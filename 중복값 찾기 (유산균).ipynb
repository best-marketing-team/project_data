# %%
lst1 = [4, 9, 1, 17, 11, 26, 28, 54, 69]
lst2 = [9, 9, 74, 21, 45, 11, 63, 28, 26]
lst3 = [value for value in lst1 if value in lst2]
print(lst3)
# Out:
# [9, 11, 26, 28]

# %%
import pandas as pd

# %%
df = pd.read_csv('유산균_리뷰.csv')

# %%
df
# Out:
#       pb01   pb02    pb03   pb04       pb05   pb06   pb07   pb08    pb09  \
# 0      윤진혁   상큼남쑤     나순재    신*래         럽쏭    박*영    민순이  상큼아이린  Im지니어스
# 1      한*영   대박리뷰     신*경   tryh       미미엔젤     뿡류  예민한미각    로커스    나른하냥
# 2    넘솔직하지  핑크베이비    무배특가  넘솔직하지    Lucifer    김*경    이*정    권*희     김*주
# 3      신*림    박*주  휴우1234  메리와낭콩         샤날   솔직해라    진*영  샤르망슈슈    무배특가
# 4      박*주    블랙냥     김수현  똑똑한쇼핑        정*은  빨간머리앤  행복한딸기   하루베베   집노예도비
# ..     ...    ...     ...    ...        ...    ...    ...    ...     ...
# 691    NaN    NaN     NaN    NaN        안*영    NaN    NaN    NaN     NaN
# 692    NaN    NaN     NaN    NaN        손*우    NaN    NaN    NaN     NaN
# 693    NaN    NaN     NaN    NaN       솔메이트    NaN    NaN    NaN     NaN
# 694    NaN    NaN     NaN    NaN  hohowojja    NaN    NaN    NaN     NaN
# 695    NaN    NaN     NaN    NaN        백*원    NaN    NaN    NaN     NaN
#
#      pb10   pb11   pb12     pb13   pb14   pb15   pb16   pb17     pb18  \
# 0    럭키짱v  푸른나무숲    꼬숭내    예민한미각  친절한링링  Agwee    이*은     샤날  HAAAAAA
# 1      퍄올    신*주    김민정  ABOCLUB    김*희   지앤지앤  보랏빛엽서    장백구   포레스트11
# 2     윤*현    권*명    장백구      유보경    빛날은  3star      늪  반짝슬이맘     꽃남매맘
# 3     쏘2야   과일요정  미스트블루       뮤토    김*아    김*선    서*환   지앤지앤      장*미
# 4     길*은  마시멜로다    박*진     콩이네집  솔직냥집사    장*영    김*옥    한*지      최*자
# ..    ...    ...    ...      ...    ...    ...    ...    ...      ...
# 691   NaN    NaN    NaN      NaN    NaN    NaN    NaN    NaN      NaN
# 692   NaN    NaN    NaN      NaN    NaN    NaN    NaN    NaN      NaN
# 693   NaN    NaN    NaN      NaN    NaN    NaN    NaN    NaN      NaN
# 694   NaN    NaN    NaN      NaN    NaN    NaN    NaN    NaN      NaN
# 695   NaN    NaN    NaN      NaN    NaN    NaN    NaN    NaN      NaN
#
#           pb19
# 0          한*혜
# 1          미키키
# 2         봄봄엄마
# 3          22살
# 4    MysteryOf
# ..         ...
# 691        NaN
# 692        NaN
# 693        NaN
# 694        NaN
# 695        NaN
#
# [696 rows x 19 columns]

# %%
all_list = []
for i in range(696):
    for q in range(19):
        
        all_list.append(df.values[i][q])

# %%
all_list
# Out:
# ['윤진혁',
#  '상큼남쑤',
#  '나순재',
#  '신*래',
#  '럽쏭',
#  '박*영',
#  '민순이',
#  '상큼아이린',
#  'Im지니어스',
#  '럭키짱v',
#  '푸른나무숲',
#  '꼬숭내',
#  '예민한미각',
#  '친절한링링',
#  'Agwee',
#  '이*은',
#  '샤날',
#  'HAAAAAA',
#  '한*혜',
#  '한*영',
#  '대박리뷰',
#  '신*경',
#  'tryh',
#  '미미엔젤',
#  '뿡류',
#  '예민한미각',
#  '로커스',
#  '나른하냥',
#  '퍄올',
#  '신*주',
#  '김민정',
#  'ABOCLUB',
#  '김*희',
#  '지앤지앤',
#  '보랏빛엽서',
#  '장백구',
#  '포레스트11',
#  '미키키',
#  '넘솔직하지',
#  '핑크베이비',
#  '무배특가',
#  '넘솔직하지',
#  'Lucifer',
#  '김*경',
#  '이*정',
#  '권*희',
#  '김*주',
#  '윤*현',
#  '권*명',
#  '장백구',
#  '유보경',
#  '빛날은',
#  '3star',
#  '늪',
#  '반짝슬이맘',
#  '꽃남매맘',
#  '봄봄엄마',
#  '신*림',
#  '박*주',
#  '휴우1234',
#  '메리와낭콩',
#  '샤날',
#  '솔직해라',
#  '진*영',
#  '샤르망슈슈',
#  '무배특가',
#  '쏘2야',
#  '과일요정',
#  '미스트블루',
#  '뮤토',
#  '김*아',
#  '김*선',
#  '서*환',
#  '지앤지앤',
#  '장*미',
#  '22살',
#  '박*주',
#  '블랙냥',
#  '김수현',
#  '똑똑한쇼핑',
#  '정*은',
#  '빨간머리앤',
#  '행복한딸기',
#  '하루베베',
#  '집노예도비',
#  '길*은',
#  '마시멜로다',
#  '박*진',
#  '콩이네집',
#  '솔직냥집사',
#  '장*영',
#  '김*옥',
#  '한*지',
#  '최*자',
#  'MysteryOf',
#  '킴여사님',
#  '나순재',
#  '최지연',
#  '남석엄마',
#  '홍*환',
#  '니모이짜',
#  '한*영',
#  '안*길',
#  '하루짱',
#  '이*주',
#  '쿠쿠쿠쿠하',
#  '또연',
#  '송*안',
#  '신*현',
#  '호큐',
#  '내가오니맘',
#  '다둥맘83',
#  '김*',
#  '삼손이누나',
#  '냠냐미양',
#  '꽃보다구매',
#  '스마일웃자',
#  '이*정',
#  '듀륏cherry',
#  'HolyCross',
#  '강*연',
#  '휴우1234',
#  '나순재',
#  '강쥐냥이',
#  '브니맘',
#  '김*랑',
#  '이*비',
#  'bball',
#  '박*옥',
#  '오늘도',
#  '박*영',
#  'cherry11',
#  '여*정',
#  '내돈내산찐',
#  '김*환',
#  '한*연',
#  '최*화',
#  '임*연',
#  '아기상어v',
#  '딸둘맘2016',
#  '크리티나',
#  '두만',
#  '김링',
#  '우*영',
#  '김*현',
#  '김*경',
#  '유*주',
#  '쁘띠걸',
#  '김*연',
#  '방크',
#  '송*애',
#  '이*숙',
#  '김지연',
#  '공주야주야',
#  '정*숙',
#  '사랑투윤',
#  '김*정',
#  '한*진',
#  '집노예도비',
#  '김*경',
#  '한*연',
#  '오리너굴씨',
#  'SkyCat',
#  'snowqueen',
#  '배지현',
#  '정*민',
#  '꼬마야밥묵',
#  '이*애',
#  '김*화',
#  '차민',
#  '강*숙',
#  '라뉘',
#  '서*민',
#  '다운힐요정',
#  '도경찡맘',
#  '노란잠수함',
#  '손*희',
#  '넘솔직하지',
#  '비글다섯명',
#  '1227',
#  'smilewme',
#  '이*영',
#  '박*미',
#  '랑비엘',
#  '박*경',
#  '지민맘',
#  '정*진',
#  '윤*내',
#  '김*연',
#  '황*정',
#  '아이럽유유',
#  '네오천사',
#  '캐비아',
#  '이*미',
#  '서*미',
#  '강*주',
#  '똑똑한쇼핑',
#  '정*금',
#  '어니맘',
#  '코코랑애기',
#  '구*나',
#  '이*훈',
#  '이*림',
#  '변*영',
#  'HaHa11',
#  '이*연',
#  '유*아',
#  '김*순',
#  '제갈종근',
#  '보석마미',
#  '정*호',
#  '전*민',
#  '정한맘',
#  '나순재',
#  '김*훈',
#  '박*화',
#  '박*호',
#  '티엠I',
#  '꿔쏴',
#  '강*희',
#  '장*희',
#  '휩쓸리다',
#  '이*주',
#  '강*정',
#  '김*현',
#  '은*승',
#  '임*정',
#  '김*우',
#  '메리와낭콩',
#  '럭키짱v',
#  '길한',
#  '썸mer',
#  'Joyflix',
#  '도경찡맘',
#  '선문촬요',
#  '양*정',
#  '진*영',
#  '전*슬',
#  '윤*미',
#  '최*선',
#  '쿠리미',
#  '수지장',
#  '수달a',
#  '김*혜',
#  '이*구',
#  '딸기베베',
#  '룰루롤롤로',
#  '이*미',
#  '김*선',
#  '김*모',
#  '진니챈니R',
#  '유*숙',
#  '양*정',
#  'ABOCLUB',
#  '이*주',
#  '크리티나',
#  '로니니',
#  '김*희',
#  '신*원',
#  '하수창',
#  '이*수',
#  '권*아',
#  '김아람',
#  '박*헌',
#  '곽*욱',
#  '차*미',
#  'Top500',
#  '보석마미',
#  '하루짱',
#  '싱이맘',
#  '서뽀사랑',
#  '민1012',
#  'yeonn',
#  '아지랑이',
#  '솔찌',
#  '이*하',
#  '송*영',
#  '김*나',
#  '정*정',
#  '고*주',
#  '이*화',
#  '김*정',
#  '뭉띠띠',
#  '카운트따운',
#  '이*서',
#  'jjang22',
#  '쿠르파앙',
#  '5iro',
#  '이*서',
#  '오*주',
#  '보석마미',
#  '진*주',
#  '아랑별',
#  '한*희',
#  '콩알0l',
#  '이*경',
#  '구*애',
#  '박*정',
#  '고*남',
#  '이*민',
#  '조*나',
#  '고*경',
#  '임*훈',
#  '이*정',
#  '박*화',
#  '까페타임',
#  '하얀딸기',
#  '꽃남매맘',
#  '전*정',
#  'P*A',
#  '예진엄마',
#  '우*하',
#  '강*정',
#  '이*숙',
#  '배*호',
#  '김*덕',
#  '이*건',
#  '우*선',
#  '조*영',
#  '권*정',
#  '심*정',
#  '한*연',
#  '이*옥',
#  '김*선',
#  '신*경',
#  '권*명',
#  '파이리v',
#  '송*람',
#  '뚜기뚜밥',
#  '아껴쓰자',
#  'HoHoHo맘',
#  '스경s',
#  '박*정',
#  '정*리',
#  '유*숙',
#  '마녀의여행',
#  '초코판다',
#  '임*일',
#  '탁*지',
#  '진*경',
#  '정*화',
#  '이루아',
#  'HOYA',
#  '절약주부',
#  '강쥐냥이',
#  '비글홧팅',
#  '김*영',
#  '쇼핑은도박',
#  '김*실',
#  '신*미',
#  '하*희',
#  '송*지',
#  '눈웃음짱',
#  '이*민',
#  '이*영',
#  '홍*정',
#  '조*철',
#  '허*석',
#  '이*점',
#  '이*희',
#  '오*지',
#  '초코커피',
#  '김*혜',
#  '다롱맘628',
#  '윤*한',
#  '김*지',
#  '비글홧팅',
#  '쏘2야',
#  '키큰친구',
#  '김*경',
#  '권*비',
#  '조*희',
#  'HIRMVLEN',
#  '최철원',
#  '김*숙',
#  '유*순',
#  '김*지',
#  'gayun6716',
#  '서*수',
#  '작은앙마v',
#  '김*',
#  '떵글뱅이',
#  '우*태',
#  '연소정',
#  '신*미',
#  '포도마미',
#  '말리0313',
#  '김*은',
#  '아름다우니',
#  '길한',
#  '안*미',
#  '전*국',
#  '정*자',
#  '고*정',
#  '더나은',
#  '이*경',
#  '윤*영',
#  '이*화',
#  '김*규',
#  '김링',
#  '김*',
#  '제니의하루',
#  '미니로즈',
#  '김*람',
#  '콩순이럽',
#  '토마토케찹',
#  '장*원',
#  '이*현',
#  'frankkkk',
#  '박*숙',
#  '권*준',
#  '김*비',
#  '조*민',
#  '노*리',
#  '도움이돼용',
#  '반짝반짝영',
#  '조*연',
#  '고*경',
#  '오소리홧팅',
#  '정*진',
#  '이*리',
#  '별별님',
#  '삐약2',
#  '온유베베',
#  '김*영',
#  '리로리르리',
#  '김*범',
#  'hm86park',
#  '김*혜',
#  '김*희',
#  '이*주',
#  '소곱창대창',
#  '김*영',
#  '박*은',
#  '빛으로물든',
#  '차*희',
#  '김*기',
#  '티엠I',
#  '이쁜별님',
#  'Renewel',
#  '이*민',
#  '설종기',
#  '백*현',
#  '오*정',
#  '최*늬',
#  '김*연',
#  '라햄',
#  'lovefish',
#  '유*경',
#  '손*희',
#  '김*송',
#  '배*아',
#  '오명숙',
#  '박*수',
#  '백*숙',
#  '이*호',
#  '초록미녀',
#  '욱찌',
#  '임*영',
#  '베키양',
#  '김루비L',
#  '최고의쇼핑',
#  '김*훈',
#  '이*실',
#  '김*화',
#  '김*주',
#  '마망드J',
#  '정*희',
#  '이*서',
#  '유*늘',
#  '양*규',
#  '조*경',
#  '웃음전도사',
#  '좌*희',
#  '박*민',
#  '가성비보이',
#  '현현파파',
#  '김*주',
#  '이*나',
#  '챔프와챔구',
#  '윤*한',
#  '김*현',
#  '강*란',
#  '최주연',
#  '챠밍밍',
#  '최*라',
#  '미쓰홍당무',
#  '최*희',
#  '김*기',
#  '김*희',
#  '미미29',
#  '조*진',
#  '도로롱동',
#  '쪼롱이',
#  '정길동',
#  '방방코스터',
#  '김*솔',
#  '신*용',
#  '인트제',
#  '전*',
#  '사랑투윤',
#  '김*곤',
#  '엄*선',
#  '문지현',
#  '박*미',
#  '디자이너앤',
#  '양*아',
#  '김*배',
#  '김*은',
#  '힙꽁',
#  '정*원',
#  '김*지',
#  '권*우',
#  '이*희',
#  '소보류',
#  'narang',
#  '반지름',
#  'y7e77',
#  '세빛쭌',
#  '잠실겸둥이',
#  '정*안',
#  '서*훈',
#  '박*승',
#  '윤*정',
#  '김*영',
#  '한*원',
#  '김*나',
#  '이*연',
#  '여니e',
#  '김*은',
#  '일등주부',
#  '최*인',
#  '탈*원',
#  '넬리쥬',
#  '박*선',
#  '김*정',
#  '과일요정',
#  '화니마마',
#  'Han86',
#  '강*라',
#  '황*희',
#  '박*현',
#  '박*순',
#  '윤*미',
#  '고*진',
#  '이*민',
#  '김*화',
#  '오*영',
#  '배*혜',
#  '최*희',
#  '서*미',
#  '이*기',
#  '서*채',
#  '둣거비',
#  '이*원',
#  '육아장인',
#  '쏘쏘이',
#  '허*지',
#  '이*옥',
#  '과일요정',
#  'Pig',
#  '김*란',
#  '김*혜',
#  'J*G',
#  '한주부님',
#  '꼬르륵',
#  '김*희',
#  '이*범',
#  '쩰리7',
#  '권*희',
#  'narang',
#  '꼬마카붕붕',
#  '신은정',
#  'LUls2',
#  '오*화',
#  '윤*영',
#  '박*영',
#  '김*국',
#  '심*석',
#  '도리뱅뱅',
#  '박*민',
#  '홍*주',
#  '유*정',
#  '키로',
#  '양*선',
#  '이*미',
#  '유*온',
#  '나이테21',
#  '박*연',
#  'MinimalN',
#  '박*선',
#  '쏘2야',
#  '이봄',
#  '윤슬기',
#  '배*영',
#  '메리와낭콩',
#  '와니벼리맘',
#  '쇼핑맨날해',
#  '이*온',
#  '김*규',
#  '한*희',
#  '이*성',
#  '김*혜',
#  '장*순',
#  '김규희',
#  '백*윤',
#  '푸린',
#  '주*아',
#  '이*원',
#  '뽀미뽀미맘',
#  '물먹는팬더',
#  '송*나',
#  '최*화',
#  '별별님',
#  '김*희',
#  '오*연',
#  '조*희',
#  '오렝지냥이',
#  '최*정',
#  '꽁이07',
#  '박*열',
#  '날래댁',
#  '이*정',
#  '가뿐',
#  '김*영',
#  '손*희',
#  '정*경',
#  '비글홧팅',
#  '이개',
#  '편*정',
#  '아이예뻐라',
#  '김*경',
#  '짱탄뿡',
#  '최*지',
#  '최*우',
#  '박*선',
#  '임*문',
#  '갬갬',
#  '고*우',
#  '장*연',
#  '이*영',
#  '피*화',
#  '구*정',
#  '이*봉',
#  '강*수',
#  '박*미',
#  '김하정',
#  '김*애',
#  '김*엽',
#  '하율맘',
#  '염*희',
#  '윤*민',
#  '장*숙',
#  '고*우',
#  '이*리',
#  '닉네임55',
#  '강*정',
#  '이*우',
#  '진*수',
#  '이*식',
#  '서*정',
#  '강*주',
#  '채*정',
#  '정*이',
#  '금피마르소',
#  '소*나',
#  '강*진',
#  '한*용',
#  '야뚱',
#  '여보세용',
#  '두더지여왕',
#  '홍여보마눌',
#  '송*경',
#  '정*빈',
#  '이*현',
#  '손*주',
#  '정*솔',
#  '리뷰한다',
#  '장*래',
#  '강*지',
#  '신*봉',
#  '강*기',
#  '서*지',
#  '뀽뀨꾸루꿍',
#  '남석엄마',
#  '안*정',
#  '리사리사',
#  '김*경',
#  '만듦쟁이',
#  '황*옥',
#  '이*윤',
#  '김*란',
#  '이*민',
#  '김*연',
#  '최*순',
#  '최*희',
#  '별린',
#  '박*철',
#  '박*연',
#  '이*늘',
#  '국*희',
#  '방*란',
#  '쟈니그랜마',
#  '김지선',
#  '아르르름',
#  'Bernard',
#  '송*화',
#  '김*솔',
#  '바니마미',
#  '성*모',
#  '곽*신',
#  '연두부',
#  '임*아',
#  '한*름',
#  '이*정',
#  '원*호',
#  '김*용',
#  '박*미',
#  '정*영',
#  '김*형',
#  '김*숙',
#  '김*연',
#  '노란고양이',
#  '잇츠쿠우팡',
#  '행복에나라',
#  '박*은',
#  '아직신혼',
#  '하랑mommy',
#  '이음e',
#  '초로밍',
#  '가가단',
#  '럭셔리강',
#  '강*숙',
#  '크리티나',
#  '권*진',
#  '조*숙',
#  '윤*진',
#  '도담댁',
#  '방*숙',
#  '윤*후',
#  '윤*수',
#  '쿠리부인',
#  'Lipsgirl',
#  '이*애',
#  '타르6mg',
#  '최*미',
#  'V럭키맘v',
#  '티엠I',
#  '최*은',
#  '신*리',
#  '한아름',
#  '김*주',
#  '오*인',
#  '방*은',
#  '최*숙',
#  '김*진',
#  '전*옥',
#  '김*정',
#  '문*희',
#  '허*주',
#  'Dohee',
#  '탁*지',
#  '송*옥',
#  '유미미',
#  '송*름',
#  '김*진',
#  '조*지',
#  '한*미',
#  '쏘쏘쏘쏘',
#  '김*영',
#  '토토니',
#  '안*정',
#  'gaeulyc',
#  '김*진',
#  '권*심',
#  '김*영',
#  '김*준',
#  '정*안',
#  '임*미',
#  '김*홍',
#  '김*정',
#  '조*림',
#  '오*희',
#  '상큼아이린',
#  '초*화',
#  '어린앙자별',
#  '손*리',
#  '김*정',
#  '강*샘',
#  '장칼국수',
#  '류*현',
#  '박*영',
#  '박*란',
#  '신*욱',
#  '이*희',
#  '이*숙',
#  '정*재',
#  '김*희',
#  '이*람',
#  '꽁야',
#  '손예지',
#  '한*정',
#  '조*람',
#  '김*희',
#  '최*정',
#  '김*라',
#  '배*정',
#  '박*화',
#  '한*현',
#  '수림정',
#  '이지선',
#  '갑을병정',
#  'Teddymom',
#  '오*민',
#  '조*희',
#  '정*진',
#  '김*미',
#  '임*영',
#  '김*현',
#  'jamjari',
#  '꽃님엄마00',
#  '우*영',
#  '박*한',
#  '키티사랑S2',
#  '송*정',
#  '이*영',
#  '장*희',
#  '염*롱',
#  '임*아',
#  '이*',
#  '최*혁',
#  '강*수',
#  '서*경',
#  '차*이',
#  '이*원',
#  '삐아삐아',
#  '프린스맘',
#  '이*찬',
#  '이*숙',
#  '편*정',
#  '박*리',
#  '이*람',
#  '반짝슬이맘',
#  '권*령',
#  '손*희',
#  '박*연',
#  '손*수',
#  '장*정',
#  '배*민',
#  'astonishin',
#  '손*숙',
#  '서*연',
#  '최*희',
#  '행복하자v',
#  '김*이',
#  '노*욱',
#  '전*철',
#  '이*원',
#  '이*숙',
#  '참이슬공주',
#  '함*진',
#  '구찌베니',
#  '포레스트11',
#  '박*임',
#  '이*미',
#  '정*옥',
#  '이*영',
#  '안*정',
#  '이*현',
#  '김*숙',
#  '김랄랄라',
#  '서*영',
#  '임*지',
#  '들깨',
#  '사용후기꾼',
#  'Minmini',
#  '송*슬',
#  '미니베이비',
#  '사용후기꾼',
#  '말리0313',
#  '우만동새댁',
#  '김*일',
#  '오*아',
#  '강*람',
#  '장*은',
#  '김*수',
#  '박*연',
#  '조*지',
#  '문*희',
#  '일등주부',
#  '박*은',
#  '꺄륵꺄르륵',
#  '차*나',
#  '연소정',
#  '강*영',
#  '유*순',
#  '쿡크다쓰',
#  '이*희',
#  '권*슬',
#  '김*은',
#  '김*정',
#  '이*주',
#  '김*경',
#  '안*학',
#  '저하늘꽃',
#  '김*연',
#  '김*선',
#  'Simon',
#  '권*진',
#  '유*경',
#  '김*현',
#  '강*희',
#  '뽀미뽀미맘',
#  '강*안',
#  '조*빈',
#  '김*심',
#  '정한맘',
#  '지*아',
#  '마음기쁨',
#  '조*주',
#  '달봉이지',
#  '최*아',
#  'ktgdugg',
#  '후았따쒸',
#  '정*숙',
#  '안*남',
#  'Smyang',
#  '최*미',
#  '박*숙',
#  '이*동',
#  '문*희',
#  '최*진',
#  '중간천사',
#  '이*성',
#  '이*주',
#  '이시도르',
#  '내맘니맘',
#  '그런사람',
#  '차연진',
#  'M*N',
#  '이*선',
#  '고*련',
#  '이*경',
#  '김*옥',
#  '지*아',
#  '황*림',
#  '최재현',
#  '신*주',
#  '김*미',
#  '허*지',
#  '지아지오맘',
#  '유*희',
#  '복도치',
#  '이*진',
#  '솔직헌',
#  '김지유',
#  '김*령',
#  '김*영',
#  '엄*익',
#  '김*지',
#  '김*민',
#  '이*현',
#  '김*영',
#  '김*영',
#  '황*은',
#  '클럽엔젤',
#  '장*화',
#  '솔비랑별이',
#  '박*용',
#  'y7e77',
#  '신*우',
#  '이헬창',
#  '유*정',
#  '엄*인',
#  '류재은',
#  '한*랑',
#  '민트초코v',
#  '이*은',
#  '김*민',
#  '황*미',
#  '유우라',
#  '김*서',
#  '정*화',
#  '김*옥',
#  '천추천이',
#  '김*옥',
#  '박*관',
#  '김*신',
#  '구름앙',
#  '황*주',
#  '이*우',
#  '소피루비',
#  '김*우',
#  '파푸맘',
#  '김*선',
#  '황*정',
#  '강*근',
#  '박*아',
#  '김*선',
#  '최*아',
#  ...]

# %%
duplicate_list = []
for i in all_list:
    if all_list.count('i') >=2:
        duplicate_list.append(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-887dfabc6614> in <module>
# ----> 1 all_list.duplicated()
#
# AttributeError: 'list' object has no attribute 'duplicated'

# %%
all_list.count('나순재')
# Out:
# 4
