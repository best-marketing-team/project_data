# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time

# %%
key = 'b61966717cb94ba4b8a4'

# %%
url = 'http://openapi.foodsafetykorea.go.kr/api/b61966717cb94ba4b8a4/C003/xml/1/10'

# %%
req = requests.get(url)
print(type(req))
# Out:
# <class 'requests.models.Response'>

# %%
html = req.text

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
text = soup.find().text.replace('\n','').replace("\.","")

# %%
text
# Out:
# '0ERROR-301파일타입 값이 누락 혹은 유효하지 않습니다. 요청인자 중 TYPE을 확인하십시오.'

# %%
type(text)
# Out:
# str

# %%
[x.text for x in finded_values][0:1]
# Out:
# ['\n29819\n\nINFO-000\n정상처리되었습니다.\n\n\n1일 3회, 1회2캡슐(250mg/1캡슐) 식전 또는 식후에 물과 함께 섭취\n영양칼슘비타민\n유청칼슘(칼슘함량20%이상),비타민B1질산염,비타민C(함량 100%),판토텐산칼슘,나이아신(함량 100%),카제인포스포펩타이드(c.pp)\n20040302\n2015-05-22 00:00:00.0\n제조일로부터 2년\n200400150395\n①뼈와 치아 형성에 필요②신경과 근육 기능 유지에 필요③정상적인 혈액응고에 필요④청년기 이전에 적절한 운동과 건강한 식습관을 유지하면서 충분한 칼슘을 섭취하면 향후 골다공증발생의 위험을 감소시킬 수 있음\r\r\n①탄수화물과 에너지 대사에 필요\r\r\n①결합조직 형성과 기능유지에 필요②철의 흡수에 필요③유해산소로부터 세포를 보호하는데 필요\r\r\n①뼈와 치아 형성에 필요②신경과 근육 기능 유지에 필요③정상적인 혈액응고에 필요④청년기 이전에 적절한 운동과 건강한 식습관을 유지하면서 충분한 칼슘을 섭취하면 향후 골다공증발생의 위험을 감소시킬 수 있음\r\r\n①체내 에너지 생성에 필요\n\n고려인삼과학주식회사\n2015-05-22 00:00:00.0\n20040015039\n1. 성상 : 녹색의 경질캅셀로 이미, 이취가 없어야 한다\r\n2. 대장균군 : 음성\r\n3. 붕해시험 : 건강기능식품공전 III.2 붕해도 시험의 캅셀제품 시험법에 따라 20분내에 붕해\r\n4. 칼슘 : 표시량(285.9mg/1500mg)의 80~150%\r\n5. 비타민B1 : 표시량(1.875mg/1500mg)의 80~180%\r\n6. 비타민C : 표시량(49.5mg/1500mg)의 80~150%\r\n7. 판토텐산 칼슘 : 표시량(4.5mg/1500mg)의 80~180%\r\n8. 나이아신 : 표시량(13.5mg/1500mg)의 80~150%\n물과 함께 섭취한다.1)의약품과 함께 섭취하지 마세요\r\n2)특이체질 등 알러지 체질의 경우 성분을 확인 후 섭취하세요\n불투명
# ...
